# %%
#intro to python

# %% [markdown]
# bu sayfada python ve oandas çalışıyoruz

# %%
 # $ \int_a^b\frac{dx}{sinx}\thetha\sigma $

# %% [markdown]
# # Yeni Bölüm

# %%
#değişken tanımlama

# %%
a=5
b=3
c=a*b
print(c)
# Out:
# 15

# %%
yıl=2012

# %%
'merhaba dünya'*10
# Out:
# 'merhaba dünyamerhaba dünyamerhaba dünyamerhaba dünyamerhaba dünyamerhaba dünyamerhaba dünyamerhaba dünyamerhaba dünyamerhaba dünya'

# %%
for i in range(100):
    print('merhaba dünya')
# Out:
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# merhaba dünya
# ...

# %%
#veri tipleri
#1-string (yazı,metin,text),sözel veri bunları tek tırnek çift tırnak  veya üç tırnak içine yazarız
#float ondalık sayı

# %%
d="dünya"
d='dünya'
d='''dünya'''
d="O'Connor"
d='''Ali'nin babası dedi ki"merhaba"'''

# %%
#listeler

# %%
liste1=[1,4,6,'ali','veli']

# %%
#dictionary sozluk

# %%
sozluk={'key:açıklaması'}

# %%
for i in liste1:
  print(i)
# Out:
# 1
# 4
# 6
# ali
# veli

# %%
#fonksiyonlar

# %%
fiyat=[25,67,89,100,90]

# %%
#DRY-do not repeat yourself

# %%
def tax(x):
  return x*1.60

# %%
tax(78)
# Out:
# 124.80000000000001

# %%
for i in fiyat:
  print(tax(i))
# Out:
# 40.0
# 107.2
# 142.4
# 160.0
# 144.0

# %%
#list comprehension

# %%
[tax(x) for x in fiyat ]
# Out:
# [40.0, 107.2, 142.4, 160.0, 144.0]

# %%
#operatörler

# %%
#Aritmatik operatörler + - * \ %

# %%
#Mantıksal operatörler <,>,==,!=or | < &

# %%
import pandas as pd

# %%
#dataframe df -tablo
df=pd.read_csv('/content/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Gender   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender'].value_counts()
# Out:
# male      577
# female    314
# Name: Gender, dtype: int64

# %%
df['Gender'].value_counts(normalize=True)
# Out:
# male      0.647587
# female    0.352413
# Name: Gender, dtype: float64

# %%
df[df['Age']<18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df.columns=df.columns.str.upper()

# %%
df.head()
# Out:
#    PASSENGERID  SURVIVED  PCLASS  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 NAME  GENDER   AGE  SIBSP  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    PARCH            TICKET     FARE CABIN EMBARKED
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2=pd.read_excel('/sales-funnel.xlsx')
df2
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
#pip install xlrd

# %%
df.head()
# Out:
#    PASSENGERID  SURVIVED  PCLASS  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 NAME  GENDER   AGE  SIBSP  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    PARCH            TICKET     FARE CABIN EMBARKED
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df3=pd.read_xml('/catalog.xml')
df3.head()
# Out:
#                 COMMON               BOTANICAL ZONE         LIGHT  PRICE  \
# 0            Bloodroot  Sanguinaria canadensis    4  Mostly Shady  $2.44
# 1            Columbine    Aquilegia canadensis    3  Mostly Shady  $9.37
# 2       Marsh Marigold        Caltha palustris    4  Mostly Sunny  $6.81
# 3              Cowslip        Caltha palustris    4  Mostly Shady  $9.90
# 4  Dutchman's-Breeches     Dicentra cucullaria    3  Mostly Shady  $6.44
#
#    AVAILABILITY
# 0         31599
# 1         30699
# 2         51799
# 3         30699
# 4         12099

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)')[2]
df.head()
# Out:
#   Country/Territory IMF[1][13]            World Bank[14]             \
#   Country/Territory   Forecast       Year       Estimate       Year
# 0             World  109529216       2024      100879560       2022
# 1     United States   28781083       2024       25439700       2022
# 2             China   18532633  [n 1]2024       17963171  [n 3]2022
# 3           Germany    4591100       2024        4082469       2022
# 4             Japan    4110452       2024        4256410       2022
#
#   United Nations[15]
#             Estimate       Year
# 0          100834796       2022
# 1           25744100       2022
# 2           17963170  [n 1]2022
# 3            4076923       2022
# 4            4232173       2022

# %%
df.to_excel('gdp.xlsx')

# %%
df3=pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_number_of_scientific_and_technical_journal_articles')[2]
df3.head()
# Out:
#    Rank   Country or Territory    Count     Share  Population  \
# 0   1.0                  China  27736.0  23171.84  1409670000
# 1   2.0          United States  29165.0  20292.72   335893238
# 2   NaN  Schengen area[Note 1]      NaN  15618.76   453324255
# 3   3.0                Germany   9347.0   4318.69    84607016
# 4   4.0         United Kingdom   8880.0   3701.99    67596281
#
#    Count per ten million people  Share per ten million people
# 0                         197.0                        164.38
# 1                         868.0                        604.14
# 2                           NaN                        344.54
# 3                        1105.0                        510.44
# 4                        1314.0                        547.66

# %%
pip install gtts

# %%
from gtts import gTTS

# %%
text='Yapay zeka dersini nasıl buldunuz eğlenceli değil mi?'
kayıt=gTTS(text=text,lang='tr',slow=False)
kayıt.save('robot.mp3')
